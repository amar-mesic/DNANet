# %%
# %cd /Users/amarmesic/Documents/tudelft/thesis/DNANet
# Out:
# /Users/amarmesic/Documents/tudelft/thesis/DNANet
# /Users/amarmesic/miniconda3/envs/dnanet/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
import pandas as pd
from DNAnet.data.kit_compatibility.format_conversion import individualize_genotypes

# %%
in_file  = "resources/data/ProvedIt/PROVEDIt_RD14-0003_GF_Known_Genotypes.xlsx"

out_dir  = "resources/data/ProvedIt/References_All_Loci"      # must already exist
id_col   = ["Sample ID", "Research ID"]
# Out:
# 'resources/data/ProvedIt/PROVEDIt_RD14-0003_GF_Known_Genotypes.xlsx'

# %%
# Generate one CSV per sample, keeping every locus
individualize_genotypes(
    input_path=in_file,
    file_type="excel",
    exclude_columns=id_col,  # no loci excluded
    output_dir=out_dir,
)
